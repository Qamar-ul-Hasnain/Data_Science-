# %%
import pandas as pd

df = pd.read_csv("C:/Users/DELL/Downloads/employees.csv")
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
# Create DataFrame
df = pd.DataFrame(df)

# Split email into username and domain, then create the username column
df['username'] = df['email'].str.split('@').str[0]

# Display the DataFrame
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
# Define a dictionary mapping job titles to salaries
salary = {
    'President': 200000,
    'VP Sales': 150000,
    'VP Marketing': 150000,
    'Sales Manager (APAC)': 120000,
    'Sale Manager (EMEA)': 120000,
    'Sales Manager (NA)': 120000,
    'Sales Rep': 80000
}

# Map job titles to salaries and create a new salary column
df['salary'] = df['jobTitle'].map(salary)

# Display the DataFrame
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
df = pd.DataFrame(df)


salaries = df[df['username'].isin(['mnishi', 'mgerard'])][['username', 'salary']]


print(salaries)
# Out:
#    username   salary
# 20   mnishi  80000.0
# 22  mgerard  80000.0

# %%
df = pd.DataFrame(df)


df['reportsTo'] = df['reportsTo'].fillna(method='bfill')


df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7200\1238070169.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['reportsTo'] = df['reportsTo'].fillna(method='bfill')
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# ...

# %%
df = pd.DataFrame(df)
mean_reportsTo = df['reportsTo'].mean()


# Display the mean
print(f"Mean of 'reportsTo': {mean_reportsTo}")
# Out:
# Mean of 'reportsTo': 1112.391304347826

# %%
df.describe()
# Out:
#        employeeNumber  officeCode    reportsTo         salary
# count       25.000000   23.000000    23.000000      23.000000
# mean      1310.880000    3.652174  1112.391304   96521.739130
# std        230.378551    2.102135   119.851324   32137.304245
# min       1002.000000    1.000000  1002.000000   80000.000000
# 25%       1102.000000    1.500000  1056.000000   80000.000000
# 50%       1286.000000    4.000000  1102.000000   80000.000000
# 75%       1504.000000    5.500000  1143.000000  100000.000000
# max       1702.000000    7.000000  1621.000000  200000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employeeNumber  25 non-null     int64
#  1   lastName        24 non-null     object
#  2   firstName       23 non-null     object
#  3   extension       23 non-null     object
#  4   email           23 non-null     object
#  5   officeCode      23 non-null     float64
#  6   reportsTo       23 non-null     float64
#  7   jobTitle        23 non-null     object
#  8   username        23 non-null     object
#  9   salary          23 non-null     float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ KB

# %%
df.isnull().sum()
# Out:
# employeeNumber    0
# lastName          1
# firstName         2
# extension         2
# email             2
# officeCode        2
# reportsTo         2
# jobTitle          2
# username          2
# salary            2
# dtype: int64

# %%
df.head(3)
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1002     Murphy     Diane     x5800
# 1            1056  Patterson      Mary     x4611
# 2            1076   Firrelli      Jeff     x9273
#
#                             email  officeCode  reportsTo      jobTitle  \
# 0    dmurphy@classicmodelcars.com         1.0     1002.0     President
# 1  mpatterso@classicmodelcars.com         1.0     1002.0      VP Sales
# 2  jfirrelli@classicmodelcars.com         1.0     1002.0  VP Marketing
#
#     username    salary
# 0    dmurphy  200000.0
# 1  mpatterso  150000.0
# 2  jfirrelli  150000.0

# %%
print(df["employeeNumber"].duplicated().sum())
df
# Out:
# 2
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
df.drop_duplicates("employeeNumber")
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
import pandas as pd

df = pd.read_csv("C:/Users/DELL/Downloads/employees.csv")
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
df.isnull().sum()
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
import numpy as np
df.replace(np.nan,"Qaaamar")
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
df["officeCode"]=df["officeCode"].replace(np.nan,27.36)

print(df["officeCode"].mean())
df
# Out:
# 5.5488
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
import pandas as pd

df = pd.read_csv("C:/Users/DELL/Downloads/employees.csv")
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
df.fillna(method="ffill")
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7200\1737168024.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# ...

# %%
import pandas as pd

Data = pd.read_csv("C:/Users/DELL/Downloads/employees.csv")
Data
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
import pandas as pd

# Sample data
data = {
    'employeeNumber': [1002, 1056, 1076, 1088, 1102, 1143, 1165, 1166, 1188, 1216, 1286, 1323, 1337, 1370, 1401, 1501, 1504, 1611, 1612, 1619, 1621, 1625, 1702],
    'lastName': ['Murphy', 'Patterson', 'Firrelli', 'Patterson', 'Bondur', 'Bow', 'Jennings', 'Thompson', 'Firrelli', 'Patterson', 'Tseng', 'Vanauf', 'Bondur', 'Hernandez', 'Castillo', 'Bott', 'Jones', 'Fixter', 'Marsh', 'King', 'Nishi', 'Kato', 'Gerard'],
    'firstName': ['Diane', 'Mary', 'Jeff', 'William', 'Gerard', 'Anthony', 'Leslie', 'Leslie', 'Julie', 'Steve', 'Foon Yue', 'George', 'Loui', 'Gerard', 'Pamela', 'Larry', 'Barry', 'Andy', 'Peter', 'Tom', 'Mami', 'Yoshimi', 'Martin'],
    'extension': ['x5800', 'x4611', 'x9273', 'x4871', 'x5408', 'x5428', 'x3291', 'x4065', 'x2173', 'x4334', 'x2248', 'x4102', 'x6493', 'x2028', 'x2759', 'x2311', 'x102', 'x101', 'x102', 'x103', 'x101', 'x102', 'x2312'],
    'email': ['dmurphy@classicmodelcars.com', 'mpatterso@classicmodelcars.com', 'jfirrelli@classicmodelcars.com', 'wpatterson@classicmodelcars.com', 'gbondur@classicmodelcars.com', 'abow@classicmodelcars.com', 'ljennings@classicmodelcars.com', 'lthompson@classicmodelcars.com', 'jfirrelli@classicmodelcars.com', 'spatterson@classicmodelcars.com', 'ftseng@classicmodelcars.com', 'gvanauf@classicmodelcars.com', 'lbondur@classicmodelcars.com', 'ghernande@classicmodelcars.com', 'pcastillo@classicmodelcars.com', 'lbott@classicmodelcars.com', 'bjones@classicmodelcars.com', 'afixter@classicmodelcars.com', 'pmarsh@classicmodelcars.com', 'tking@classicmodelcars.com', 'mnishi@classicmodelcars.com', 'ykato@classicmodelcars.com', 'mgerard@classicmodelcars.com'],
    'officeCode': [1, 1, 1, 6, 4, 1, 1, 1, 2, 2, 3, 3, 4, 4, 4, 7, 7, 6, 6, 6, 5, 5, 4],
    'reportsTo': [None, 1002, 1002, 1056, 1056, 1056, 1143, 1143, 1143, 1143, 1143, 1143, 1102, 1102, 1102, 1102, 1102, 1088, 1088, 1088, 1056, 1621, 1102],
    'jobTitle': ['President', 'VP Sales', 'VP Marketing', 'Sales Manager (APAC)', 'Sale Manager (EMEA)', 'Sales Manager (NA)', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep']
}

# Create DataFrame
df = pd.DataFrame(data)

# Add a new column 'bonus' with dummy data
df['bonus'] = [5000, 4000, 4000, 3000, 3000, 3000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 1500, 1500, 1000, 1000, 1000, 500, 500, 500]

# Display the updated DataFrame
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
import pandas as pd

# Sample data
data = {
    'employeeNumber': [1002, 1056, 1076, 1088, 1102, 1143, 1165, 1166, 1188, 1216, 1286, 1323, 1337, 1370, 1401, 1501, 1504, 1611, 1612, 1619, 1621, 1625, 1702],
    'lastName': ['Murphy', 'Patterson', 'Firrelli', 'Patterson', 'Bondur', 'Bow', 'Jennings', 'Thompson', 'Firrelli', 'Patterson', 'Tseng', 'Vanauf', 'Bondur', 'Hernandez', 'Castillo', 'Bott', 'Jones', 'Fixter', 'Marsh', 'King', 'Nishi', 'Kato', 'Gerard'],
    'firstName': ['Diane', 'Mary', 'Jeff', 'William', 'Gerard', 'Anthony', 'Leslie', 'Leslie', 'Julie', 'Steve', 'Foon Yue', 'George', 'Loui', 'Gerard', 'Pamela', 'Larry', 'Barry', 'Andy', 'Peter', 'Tom', 'Mami', 'Yoshimi', 'Martin'],
    'extension': ['x5800', 'x4611', 'x9273', 'x4871', 'x5408', 'x5428', 'x3291', 'x4065', 'x2173', 'x4334', 'x2248', 'x4102', 'x6493', 'x2028', 'x2759', 'x2311', 'x102', 'x101', 'x102', 'x103', 'x101', 'x102', 'x2312'],
    'email': ['dmurphy@classicmodelcars.com', 'mpatterso@classicmodelcars.com', 'jfirrelli@classicmodelcars.com', 'wpatterson@classicmodelcars.com', 'gbondur@classicmodelcars.com', 'abow@classicmodelcars.com', 'ljennings@classicmodelcars.com', 'lthompson@classicmodelcars.com', 'jfirrelli@classicmodelcars.com', 'spatterson@classicmodelcars.com', 'ftseng@classicmodelcars.com', 'gvanauf@classicmodelcars.com', 'lbondur@classicmodelcars.com', 'ghernande@classicmodelcars.com', 'pcastillo@classicmodelcars.com', 'lbott@classicmodelcars.com', 'bjones@classicmodelcars.com', 'afixter@classicmodelcars.com', 'pmarsh@classicmodelcars.com', 'tking@classicmodelcars.com', 'mnishi@classicmodelcars.com', 'ykato@classicmodelcars.com', 'mgerard@classicmodelcars.com'],
    'officeCode': [1, 1, 1, 6, 4, 1, 1, 1, 2, 2, 3, 3, 4, 4, 4, 7, 7, 6, 6, 6, 5, 5, 4],
    'reportsTo': [None, 1002, 1002, 1056, 1056, 1056, 1143, 1143, 1143, 1143, 1143, 1143, 1102, 1102, 1102, 1102, 1102, 1088, 1088, 1088, 1056, 1621, 1102],

    'jobTitle': ['President', 'VP Sales', 'VP Marketing', 'Sales Manager (APAC)', 'Sale Manager (EMEA)', 'Sales Manager (NA)', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep']
}




# Create DataFrame
df = pd.DataFrame(data)

# Add a new column 'bonus' with dummy data
df['bonus'] = [5000, 4000, 4000, 3000, 3000, 3000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 1500, 1500, 1000, 1000, 1000, 500, 500, 500]

# Create 'GetBonus' column based on the 'bonus' column
df['GetBonus'] = np.where(df['bonus'] == 0, 'no bonus', 'bonus')

# Display the updated DataFrame
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
import pandas as pd

# Sample data
data = {
    'employeeNumber': [1002, 1056, 1076, 1088, 1102, 1143, 1165, 1166, 1188, 1216, 1286, 1323, 1337, 1370, 1401, 1501, 1504, 1611, 1612, 1619, 1621, 1625, 1702],
    'lastName': ['Murphy', 'Patterson', 'Firrelli', 'Patterson', 'Bondur', 'Bow', 'Jennings', 'Thompson', 'Firrelli', 'Patterson', 'Tseng', 'Vanauf', 'Bondur', 'Hernandez', 'Castillo', 'Bott', 'Jones', 'Fixter', 'Marsh', 'King', 'Nishi', 'Kato', 'Gerard'],
    'firstName': ['Diane', 'Mary', 'Jeff', 'William', 'Gerard', 'Anthony', 'Leslie', 'Leslie', 'Julie', 'Steve', 'Foon Yue', 'George', 'Loui', 'Gerard', 'Pamela', 'Larry', 'Barry', 'Andy', 'Peter', 'Tom', 'Mami', 'Yoshimi', 'Martin'],
    'extension': ['x5800', 'x4611', 'x9273', 'x4871', 'x5408', 'x5428', 'x3291', 'x4065', 'x2173', 'x4334', 'x2248', 'x4102', 'x6493', 'x2028', 'x2759', 'x2311', 'x102', 'x101', 'x102', 'x103', 'x101', 'x102', 'x2312'],
    'email': ['dmurphy@classicmodelcars.com', 'mpatterso@classicmodelcars.com', 'jfirrelli@classicmodelcars.com', 'wpatterson@classicmodelcars.com', 'gbondur@classicmodelcars.com', 'abow@classicmodelcars.com', 'ljennings@classicmodelcars.com', 'lthompson@classicmodelcars.com', 'jfirrelli@classicmodelcars.com', 'spatterson@classicmodelcars.com', 'ftseng@classicmodelcars.com', 'gvanauf@classicmodelcars.com', 'lbondur@classicmodelcars.com', 'ghernande@classicmodelcars.com', 'pcastillo@classicmodelcars.com', 'lbott@classicmodelcars.com', 'bjones@classicmodelcars.com', 'afixter@classicmodelcars.com', 'pmarsh@classicmodelcars.com', 'tking@classicmodelcars.com', 'mnishi@classicmodelcars.com', 'ykato@classicmodelcars.com', 'mgerard@classicmodelcars.com'],
    'officeCode': [1, 1, 1, 6, 4, 1, 1, 1, 2, 2, 3, 3, 4, 4, 4, 7, 7, 6, 6, 6, 5, 5, 4],
    'reportsTo': [None, 1002, 1002, 1056, 1056, 1056, 1143, 1143, 1143, 1143, 1143, 1143, 1102, 1102, 1102, 1102, 1102, 1088, 1088, 1088, 1056, 1621, 1102],
    'jobTitle': ['President', 'VP Sales', 'VP Marketing', 'Sales Manager (APAC)', 'Sale Manager (EMEA)', 'Sales Manager (NA)', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep', 'Sales Rep'],
    'Salary': [5000, 4000, 4000, 3000, 3000, 3000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 1500, 1500, 1000, 1000, 1000, 500, 500, 500],
}

# Create DataFrame


# Display the DataFrame
df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
# Define a dictionary mapping job titles to salaries
salary = {
    'President': 200000,
    'VP Sales': 150000,
    'VP Marketing': 150000,
    'Sales Manager (APAC)': 120000,
    'Sale Manager (EMEA)': 120000,
    'Sales Manager (NA)': 120000,
    'Sales Rep': 80000
}

# Map job titles to salaries and create a new salary column
df['salary'] = df['jobTitle'].map(salary)

# Display the DataFrame
df


Data["Bonus"]=(df["Salary"]/100)*20
Data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[157], line 19
#      15 # Display the DataFrame
#      16 df
# ...
